# %%
using Plots
include("Project1_jl/helpers.jl")
include("Project1_jl/project1.jl")
include("Project1_jl/simple.jl")
# Out:
# WARNING: redefining constant COUNTERS
# WARNING: redefining constant PROBS
# powell_init (generic function with 1 method)

# %%
#  rgrad = rosenbrock_gradient(vec([0 0]))
#  r = rosenbrock(vec([0 0]))
x0r = rosenbrock_init();
   optimize(rosenbrock, rosenbrock_gradient, x0r, 20, "simple1")
#   optimize(powell, powell_gradient, vec([3 3 3 3]), 20, "simple3")

# f_tmp(x) = 1/2*(x'*x)
# fgrd_tmp(x) = x
# optimize(f_tmp, fgrd_tmp, vec([3 3]), 20, "simple1")
# println(t)

#   main("simple1", 3, optimize)
# Out:
# [-0.6532316251287036 0.14580278358231946 0.5780010327979024 -0.20024090811997963 0.7881076642187679 -0.08281456670237997 -0.3791030410830382 0.2614430526065466 0.8371315744391705 -0.035760975166003184 0.27735494904865254; -0.3108745061660861 0.29041079524733265 -0.6113678213626339 0.01659673288893193 -0.13561068991284667 0.35581017623686306 -0.5992883212748763 0.1686314023024087 -0.6490376785794407 -0.1611251896597789 0.788589724408228]
# [0.3131159242146557, 0.949714914068007]
# 2-element Array{Float64,1}:
#  -0.035760975166003184
#  -0.1611251896597789

# %%
# rosenbrock_gradient(vec([0 0]))
# rosenbrock(e)
# optimize(rosenbrock, rosenbrock_gradient, vec([3 3]), 20, "simple1")
#  main("simple1", 1, optimize)

# %%
f(x, y) =  x*y
# Out:
# f (generic function with 1 method)

# %%
x = -10:10
y = -10:10
# Out:
# -10:10

# %%
plot(x, y, f, seriestype = :contour)

# %%
plot(x, y, f, seriestype = :contour, levels = [-1, 1])

# %%
path = [2*randn(2) for i in 1:10]
path = Tuple.(cumsum(path))

plot!(path, c = :black)

# %%
savefig("myfancyplot.pdf")
